# %% [markdown]
# # # Import and combine glassdoor and inhersight data

# %%
import pandas as pd
import glob
import os
import re
import numpy as np

#load data
path = 'GlassdoorData/Austin/*.csv'  
all_files = glob.glob(path)   #makes a list of all file paths in that folder

#import all files in folder as a pandas dataframe
df_from_each_file = (pd.read_csv(f, encoding = 'unicode_escape', header = 0) for f in all_files)

#concat. into one dataframe
Austin_df = pd.concat(df_from_each_file, ignore_index=True)
df = Austin_df[pd.notnull(Austin_df['cons'])]

#convert date to proper datetime
import datetime
df['review_date'] = None 
df.loc[~df['date'].isna(), 'review_date' ] = df.date.dropna()\
    .apply(lambda x: re.search("(.+)\s\(.+\)", x).groups()[0])\
    .apply(lambda x: datetime.datetime.strptime(x, '%a %b %d %Y %H:%M:%S %Z%z'))


#just keep the 100 most recent score
df = df.sort_values('date',ascending = False).groupby('company').head(100)
# Out:
# /Applications/anaconda3/envs/joyiscool/lib/python3.7/site-packages/ipykernel_launcher.py:15: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   from ipykernel import kernelapp as app

# %%
df['pros'][0]
# Out:
# 'People CARE. They care about me, about my life, about my work, about the products, about my success, about my failures, about how to live the best possible work/life balance. There are no petty attitudes on my greater team of 30+, just people who understand when life happens and want you to the best work possible.'

# %%
df
#df.to_csv('1glassdoor_reviews_top100.csv')
df.to_pickle("./1glassdoor_reviews_top100.pkl")

# %%
inhersight_df = pd.read_csv('InHerSightRatings.csv')
inhersight_df.head(5)
# Out:
#        company  Overall  Paid Time Off  Ability Telecommute  Flexible Hours  \
# 0  360Training      1.9            2.2                  2.8             3.0
# 1     Accruent      3.2            4.6                  4.0             4.0
# 2       Amazon      3.0            3.5                  2.3             2.5
# 3        Apple      3.5            3.9                  2.5             2.7
# 4    Atlassian      3.4            4.0                  3.7             3.7
#
#    Social Environment  Coworkers  Wellness Initiatives  Mentorship  \
# 0                 2.4        2.0                   1.8         1.2
# 1                 3.9        3.8                   3.6         3.2
# 2                 2.6        3.3                   2.1         2.5
# 3                 3.0        4.0                   4.0         2.7
# 4                 4.0        3.0                   3.3         3.0
#
#    Maternity Leave  Family Growth Support  Employer Responsiveness  \
# 0              2.5                    1.5                      1.0
# 1              3.2                    3.1                      2.9
# 2              3.8                    3.3                      2.9
# 3              4.3                    3.7                      3.6
# 4              4.5                    3.0                      3.3
#
#    Learning Opportunities  Management Opportunities  Equal Opportunities  \
# 0                     2.0                       1.8                  1.8
# 1                     2.7                       2.7                  2.6
# 2                     3.0                       3.3                  3.6
# 3                     3.3                       3.6                  3.8
# 4                     2.7                       3.7                  3.0
#
#    Salary Satisfaction  Female Representation in Leadership  Number of Ratings
# 0                  1.5                                  1.4                5.0
# 1                  1.7                                  1.7               21.0
# 2                  3.0                                  3.0             1269.0
# 3                  3.2                                  3.6              631.0
# 4                  3.7                                  2.7                NaN

# %%
labeled_df = pd.merge(df, inhersight_df, on='company', how='outer')
#labeled_df = labeled_df[pd.notnull(labeled_df['Overall'])]
#labeled_df.index = range(len(labeled_df.index))
labeled_df

#save this datafile, we will reduce it later
#labeled_df.to_csv('Data/1GD_INS_df_full.csv')

# %%
#now only include companies that have ratings on inhersight.com
labeled_df = pd.merge(df, inhersight_df, on='company', how='outer')
labeled_df = labeled_df[pd.notnull(labeled_df['Overall'])]
labeled_df.index = range(len(labeled_df.index)) #reset index
labeled_df

#save this datafile of companies that have scores on inhersight.com
#labeled_df.to_csv('Data/GD_INS_df_wlabels.csv')
# Out:
#       Career Opportunities  Compensation and Benefits  Culture & Values  \
# 0                      1.0                        2.0               2.0
# 1                      5.0                        4.0               4.0
# 2                      3.0                        2.0               1.0
# 3                      3.0                        2.0               1.0
# 4                      1.0                        2.0               1.0
# 5                      4.0                        5.0               4.0
# 6                      1.0                        2.0               2.0
# 7                      NaN                        5.0               5.0
# 8                      NaN                        5.0               5.0
# 9                      1.0                        1.0               1.0
# 10                     3.0                        2.0               1.0
# 11                     5.0                        4.0               4.0
# 12                     1.0                        1.0               1.0
# 13                     1.0                        1.0               1.0
# 14                     1.0                        1.0               1.0
# 15                     1.0                        1.0               1.0
# 16                     1.0                        1.0               1.0
# 17                     4.0                        5.0               4.0
# 18                     5.0                        4.0               4.0
# 19                     4.0                        5.0               4.0
# 20                     1.0                        1.0               1.0
# 21                     1.0                        2.0               2.0
# 22                     1.0                        2.0               1.0
# 23                     1.0                        2.0               1.0
# 24                     NaN                        5.0               5.0
# 25                     NaN                        5.0               5.0
# 26                     5.0                        4.0               4.0
# 27                     NaN                        5.0               5.0
# 28                     1.0                        1.0               1.0
# 29                     5.0                        4.0               4.0
# ...                    ...                        ...               ...
# 6210                   4.0                        4.0               4.0
# 6211                   4.0                        4.0               4.0
# 6212                   5.0                        5.0               4.0
# 6213                   5.0                        5.0               4.0
# 6214                   5.0                        5.0               4.0
# 6215                   4.0                        4.0               4.0
# 6216                   NaN                        NaN               NaN
# 6217                   5.0                        5.0               5.0
# 6218                   NaN                        NaN               NaN
# 6219                   NaN                        NaN               NaN
# 6220                   NaN                        NaN               NaN
# 6221                   NaN                        NaN               NaN
# 6222                   NaN                        NaN               NaN
# 6223                   NaN                        NaN               NaN
# 6224                   NaN                        NaN               NaN
# 6225                   NaN                        NaN               NaN
# 6226                   5.0                        5.0               4.0
# 6227                   5.0                        5.0               5.0
# 6228                   5.0                        5.0               5.0
# 6229                   5.0                        5.0               5.0
# 6230                   5.0                        5.0               4.0
# 6231                   5.0                        5.0               5.0
# 6232                   5.0                        5.0               5.0
# 6233                   5.0                        5.0               4.0
# 6234                   5.0                        5.0               4.0
# 6235                   5.0                        5.0               4.0
# 6236                   5.0                        5.0               4.0
# 6237                   5.0                        3.0               5.0
# 6238                   5.0                        5.0               4.0
# 6239                   5.0                        5.0               4.0
#
#       Senior Management  Unnamed: 0  Unnamed: 16  Work/Life Balance  \
# 0                   2.0          68          NaN                1.0
# 1                   4.0           8          NaN                5.0
# 2                   1.0          32          NaN                3.0
# 3                   1.0          38          NaN                3.0
# 4                   1.0          45          NaN                1.0
# 5                   5.0          16          NaN                3.0
# 6                   2.0          60          NaN                1.0
# 7                   5.0          20          NaN                5.0
# 8                   5.0          23          NaN                5.0
# 9                   1.0          71          NaN                3.0
# 10                  1.0          36          NaN                3.0
# 11                  4.0           7          NaN                5.0
# 12                  1.0          76          NaN                3.0
# 13                  1.0          77          NaN                3.0
# 14                  1.0          78          NaN                3.0
# 15                  1.0          79          NaN                3.0
# 16                  1.0          73          NaN                3.0
# 17                  5.0          14          NaN                3.0
# 18                  4.0           4          NaN                5.0
# 19                  5.0          19          NaN                3.0
# 20                  1.0          89          NaN                1.0
# 21                  2.0          65          NaN                1.0
# 22                  1.0          42          NaN                1.0
# 23                  1.0          46          NaN                1.0
# 24                  5.0          25          NaN                5.0
# 25                  5.0          26          NaN                5.0
# 26                  4.0           5          NaN                5.0
# 27                  5.0          28          NaN                5.0
# 28                  1.0          75          NaN                3.0
# 29                  4.0           2          NaN                5.0
# ...                 ...         ...          ...                ...
# 6210                4.0          56          NaN                3.0
# 6211                4.0          55          NaN                3.0
# 6212                4.0          62          NaN                3.0
# 6213                5.0           3          NaN                3.0
# 6214                5.0           7          NaN                3.0
# 6215                4.0          50          NaN                3.0
# 6216                NaN          49          NaN                NaN
# 6217                4.0          11          NaN                1.0
# 6218                NaN          48          NaN                NaN
# 6219                NaN          44          NaN                NaN
# 6220                NaN          47          NaN                NaN
# 6221                NaN          46          NaN                NaN
# 6222                NaN          43          NaN                NaN
# 6223                NaN          42          NaN                NaN
# 6224                NaN          41          NaN                NaN
# 6225                NaN          45          NaN                NaN
# 6226                5.0           9          NaN                3.0
# 6227                4.0          15          NaN                1.0
# 6228                4.0          14          NaN                1.0
# 6229                4.0          13          NaN                1.0
# 6230                5.0           1          NaN                3.0
# 6231                4.0          12          NaN                1.0
# 6232                4.0          10          NaN                1.0
# 6233                4.0          65          NaN                3.0
# 6234                4.0          64          NaN                3.0
# 6235                4.0          61          NaN                3.0
# 6236                4.0          63          NaN                3.0
# 6237                3.0          70          NaN                3.0
# 6238                5.0           4          NaN                3.0
# 6239                5.0           0          NaN                3.0
#
#                                    advice_to_management  \
# 0     Hang up your boots and close the company or cr...
# 1                                                   NaN
# 2     Hopefully you've turned over the bad decisions...
# 3     Continue to value employees and allow opportun...
# 4     Having an open conversation about the company ...
# 5     Thanks to the new team. \nWe are excited and h...
# 6     Open opportunities for advancement, management...
# 7                                                   NaN
# 8                                                   NaN
# 9     Will.....run for the hills. You are the only d...
# 10    Figure out exactly how you want your company t...
# 11    Continue to communicate with employees on a re...
# 12                                 Onwards and upwards.
# 13    It would be good if the Leaders and other Mana...
# 14    Hire a woman who can sit on the back wall and ...
# 15    I want to be as positive as possible. This wil...
# 16    Management should do frequent surveys.Should o...
# 17                                                  NaN
# 18    Nothing to say. I know the ears are closed and...
# 19    I don't understand why you took a great busine...
# 20    higher pay for staff, employees are expected t...
# 21    Develop a strategy and stick with it, none of ...
# 22    Talk to you Account Managers and ASM's that ha...
# 23    Any job people take is not only a place to wor...
# 24    Stay focused on the main business which has be...
# 25    None. The CEO will read something on the Inter...
# 26    Keep up the impressive growth, but donât for...
# 27                                   Go screw yourself.
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 6210                                                NaN
# 6211                                                NaN
# 6212  Have some backbone and actually be honest with...
# 6213  Don't pretend that the recent NY Times article...
# 6214                                                NaN
# 6215  Let employees know how good of a job theyâre...
# 6216                                                NaN
# 6217                                                NaN
# 6218  Spend a little more on high level engineers, t...
# 6219                                         hire more!
# 6220                                                NaN
# 6221  With growth comes responsibility, much is chan...
# 6222  Prioritize diversity & inclusion and sustainab...
# 6223  Keep doing what you are doing!  Great supporti...
# 6224                                                NaN
# 6225                                                NaN
# 6226  Clean house, get rid of people who aren't perf...
# 6227                        Go back to giving out stock
# 6228                                                NaN
# 6229                                                NaN
# 6230                                                NaN
# 6231  Take care of your employees and theyâll take...
# 6232                             keep up the good work.
# 6233                                                NaN
# 6234                                                NaN
# 6235                                                NaN
# 6236                                                NaN
# 6237        Watch burnout and extend guarantee contract
# 6238                                                NaN
# 6239                                                NaN
#
#                                           author_info      company  ...  \
# 0               Current Employee - Anonymous Employee  360Training  ...
# 1               Current Employee - Anonymous Employee  360Training  ...
# 2              Former Employee - Office Administrator  360Training  ...
# 3              Former Employee - Office Administrator  360Training  ...
# 4                  Former Employee - Sales Management  360Training  ...
# 5               Current Employee - Anonymous Employee  360Training  ...
# 6               Current Employee - Anonymous Employee  360Training  ...
# 7                Former Employee - Anonymous Employee  360Training  ...
# 8                Former Employee - Anonymous Employee  360Training  ...
# 9               Current Employee - Anonymous Employee  360Training  ...
# 10             Former Employee - Office Administrator  360Training  ...
# 11              Current Employee - Anonymous Employee  360Training  ...
# 12              Current Employee - Anonymous Employee  360Training  ...
# 13              Current Employee - Anonymous Employee  360Training  ...
# 14              Current Employee - Anonymous Employee  360Training  ...
# 15              Current Employee - Anonymous Employee  360Training  ...
# 16              Current Employee - Anonymous Employee  360Training  ...
# 17              Current Employee - Anonymous Employee  360Training  ...
# 18              Current Employee - Anonymous Employee  360Training  ...
# 19              Current Employee - Anonymous Employee  360Training  ...
# 20              Current Employee - Anonymous Employee  360Training  ...
# 21              Current Employee - Anonymous Employee  360Training  ...
# 22                 Former Employee - Sales Management  360Training  ...
# 23                 Former Employee - Sales Management  360Training  ...
# 24               Former Employee - Anonymous Employee  360Training  ...
# 25               Former Employee - Anonymous Employee  360Training  ...
# 26              Current Employee - Anonymous Employee  360Training  ...
# 27               Former Employee - Anonymous Employee  360Training  ...
# 28              Current Employee - Anonymous Employee  360Training  ...
# 29              Current Employee - Anonymous Employee  360Training  ...
# ...                                               ...          ...  ...
# 6210  Current Employee - Seasonal Warehouse Associate       Amazon  ...
# 6211  Current Employee - Seasonal Warehouse Associate       Amazon  ...
# 6212      Current Employee - Senior Account Executive       Amazon  ...
# 6213  Current Employee - Software Development Manager       Amazon  ...
# 6214  Current Employee - Software Development Manager       Amazon  ...
# 6215  Current Employee - Seasonal Warehouse Associate       Amazon  ...
# 6216             Former Employee - Associate Director       Amazon  ...
# 6217                        Current Employee - Packer       Amazon  ...
# 6218             Former Employee - Associate Director       Amazon  ...
# 6219             Former Employee - Associate Director       Amazon  ...
# 6220             Former Employee - Associate Director       Amazon  ...
# 6221             Former Employee - Associate Director       Amazon  ...
# 6222             Former Employee - Associate Director       Amazon  ...
# 6223             Former Employee - Associate Director       Amazon  ...
# 6224             Former Employee - Associate Director       Amazon  ...
# 6225             Former Employee - Associate Director       Amazon  ...
# 6226  Current Employee - Software Development Manager       Amazon  ...
# 6227                        Current Employee - Packer       Amazon  ...
# 6228                        Current Employee - Packer       Amazon  ...
# 6229                        Current Employee - Packer       Amazon  ...
# 6230  Current Employee - Software Development Manager       Amazon  ...
# 6231                        Current Employee - Packer       Amazon  ...
# 6232                        Current Employee - Packer       Amazon  ...
# 6233      Current Employee - Senior Account Executive       Amazon  ...
# 6234      Current Employee - Senior Account Executive       Amazon  ...
# 6235      Current Employee - Senior Account Executive       Amazon  ...
# 6236      Current Employee - Senior Account Executive       Amazon  ...
# 6237                      Current Employee - Director       Amazon  ...
# 6238  Current Employee - Software Development Manager       Amazon  ...
# 6239  Current Employee - Software Development Manager       Amazon  ...
#
#      Mentorship Maternity Leave  Family Growth Support  \
# 0           1.2             2.5                    1.5
# 1           1.2             2.5                    1.5
# 2           1.2             2.5                    1.5
# 3           1.2             2.5                    1.5
# 4           1.2             2.5                    1.5
# 5           1.2             2.5                    1.5
# 6           1.2             2.5                    1.5
# 7           1.2             2.5                    1.5
# 8           1.2             2.5                    1.5
# 9           1.2             2.5                    1.5
# 10          1.2             2.5                    1.5
# 11          1.2             2.5                    1.5
# 12          1.2             2.5                    1.5
# 13          1.2             2.5                    1.5
# 14          1.2             2.5                    1.5
# 15          1.2             2.5                    1.5
# 16          1.2             2.5                    1.5
# 17          1.2             2.5                    1.5
# 18          1.2             2.5                    1.5
# 19          1.2             2.5                    1.5
# 20          1.2             2.5                    1.5
# 21          1.2             2.5                    1.5
# 22          1.2             2.5                    1.5
# 23          1.2             2.5                    1.5
# 24          1.2             2.5                    1.5
# 25          1.2             2.5                    1.5
# 26          1.2             2.5                    1.5
# 27          1.2             2.5                    1.5
# 28          1.2             2.5                    1.5
# 29          1.2             2.5                    1.5
# ...         ...             ...                    ...
# 6210        2.5             3.8                    3.3
# 6211        2.5             3.8                    3.3
# 6212        2.5             3.8                    3.3
# 6213        2.5             3.8                    3.3
# 6214        2.5             3.8                    3.3
# 6215        2.5             3.8                    3.3
# 6216        2.5             3.8                    3.3
# 6217        2.5             3.8                    3.3
# 6218        2.5             3.8                    3.3
# 6219        2.5             3.8                    3.3
# 6220        2.5             3.8                    3.3
# 6221        2.5             3.8                    3.3
# 6222        2.5             3.8                    3.3
# 6223        2.5             3.8                    3.3
# 6224        2.5             3.8                    3.3
# 6225        2.5             3.8                    3.3
# 6226        2.5             3.8                    3.3
# 6227        2.5             3.8                    3.3
# 6228        2.5             3.8                    3.3
# 6229        2.5             3.8                    3.3
# 6230        2.5             3.8                    3.3
# 6231        2.5             3.8                    3.3
# 6232        2.5             3.8                    3.3
# 6233        2.5             3.8                    3.3
# 6234        2.5             3.8                    3.3
# 6235        2.5             3.8                    3.3
# 6236        2.5             3.8                    3.3
# 6237        2.5             3.8                    3.3
# 6238        2.5             3.8                    3.3
# 6239        2.5             3.8                    3.3
#
#      Employer Responsiveness  Learning Opportunities Management Opportunities  \
# 0                        1.0                     2.0                      1.8
# 1                        1.0                     2.0                      1.8
# 2                        1.0                     2.0                      1.8
# 3                        1.0                     2.0                      1.8
# 4                        1.0                     2.0                      1.8
# 5                        1.0                     2.0                      1.8
# 6                        1.0                     2.0                      1.8
# 7                        1.0                     2.0                      1.8
# 8                        1.0                     2.0                      1.8
# 9                        1.0                     2.0                      1.8
# 10                       1.0                     2.0                      1.8
# 11                       1.0                     2.0                      1.8
# 12                       1.0                     2.0                      1.8
# 13                       1.0                     2.0                      1.8
# 14                       1.0                     2.0                      1.8
# 15                       1.0                     2.0                      1.8
# 16                       1.0                     2.0                      1.8
# 17                       1.0                     2.0                      1.8
# 18                       1.0                     2.0                      1.8
# 19                       1.0                     2.0                      1.8
# 20                       1.0                     2.0                      1.8
# 21                       1.0                     2.0                      1.8
# 22                       1.0                     2.0                      1.8
# 23                       1.0                     2.0                      1.8
# 24                       1.0                     2.0                      1.8
# 25                       1.0                     2.0                      1.8
# 26                       1.0                     2.0                      1.8
# 27                       1.0                     2.0                      1.8
# 28                       1.0                     2.0                      1.8
# 29                       1.0                     2.0                      1.8
# ...                      ...                     ...                      ...
# 6210                     2.9                     3.0                      3.3
# 6211                     2.9                     3.0                      3.3
# 6212                     2.9                     3.0                      3.3
# 6213                     2.9                     3.0                      3.3
# 6214                     2.9                     3.0                      3.3
# 6215                     2.9                     3.0                      3.3
# 6216                     2.9                     3.0                      3.3
# 6217                     2.9                     3.0                      3.3
# 6218                     2.9                     3.0                      3.3
# 6219                     2.9                     3.0                      3.3
# 6220                     2.9                     3.0                      3.3
# 6221                     2.9                     3.0                      3.3
# 6222                     2.9                     3.0                      3.3
# 6223                     2.9                     3.0                      3.3
# 6224                     2.9                     3.0                      3.3
# 6225                     2.9                     3.0                      3.3
# 6226                     2.9                     3.0                      3.3
# 6227                     2.9                     3.0                      3.3
# 6228                     2.9                     3.0                      3.3
# 6229                     2.9                     3.0                      3.3
# 6230                     2.9                     3.0                      3.3
# 6231                     2.9                     3.0                      3.3
# 6232                     2.9                     3.0                      3.3
# 6233                     2.9                     3.0                      3.3
# 6234                     2.9                     3.0                      3.3
# 6235                     2.9                     3.0                      3.3
# 6236                     2.9                     3.0                      3.3
# 6237                     2.9                     3.0                      3.3
# 6238                     2.9                     3.0                      3.3
# 6239                     2.9                     3.0                      3.3
#
#      Equal Opportunities Salary Satisfaction  \
# 0                    1.8                 1.5
# 1                    1.8                 1.5
# 2                    1.8                 1.5
# 3                    1.8                 1.5
# 4                    1.8                 1.5
# 5                    1.8                 1.5
# 6                    1.8                 1.5
# 7                    1.8                 1.5
# 8                    1.8                 1.5
# 9                    1.8                 1.5
# 10                   1.8                 1.5
# 11                   1.8                 1.5
# 12                   1.8                 1.5
# 13                   1.8                 1.5
# 14                   1.8                 1.5
# 15                   1.8                 1.5
# 16                   1.8                 1.5
# 17                   1.8                 1.5
# 18                   1.8                 1.5
# 19                   1.8                 1.5
# 20                   1.8                 1.5
# 21                   1.8                 1.5
# 22                   1.8                 1.5
# 23                   1.8                 1.5
# 24                   1.8                 1.5
# 25                   1.8                 1.5
# 26                   1.8                 1.5
# 27                   1.8                 1.5
# 28                   1.8                 1.5
# 29                   1.8                 1.5
# ...                  ...                 ...
# 6210                 3.6                 3.0
# 6211                 3.6                 3.0
# 6212                 3.6                 3.0
# 6213                 3.6                 3.0
# 6214                 3.6                 3.0
# 6215                 3.6                 3.0
# 6216                 3.6                 3.0
# 6217                 3.6                 3.0
# 6218                 3.6                 3.0
# 6219                 3.6                 3.0
# 6220                 3.6                 3.0
# 6221                 3.6                 3.0
# 6222                 3.6                 3.0
# 6223                 3.6                 3.0
# 6224                 3.6                 3.0
# 6225                 3.6                 3.0
# 6226                 3.6                 3.0
# 6227                 3.6                 3.0
# 6228                 3.6                 3.0
# 6229                 3.6                 3.0
# 6230                 3.6                 3.0
# 6231                 3.6                 3.0
# 6232                 3.6                 3.0
# 6233                 3.6                 3.0
# 6234                 3.6                 3.0
# 6235                 3.6                 3.0
# 6236                 3.6                 3.0
# 6237                 3.6                 3.0
# 6238                 3.6                 3.0
# 6239                 3.6                 3.0
#
#       Female Representation in Leadership  Number of Ratings
# 0                                     1.4                5.0
# 1                                     1.4                5.0
# 2                                     1.4                5.0
# 3                                     1.4                5.0
# 4                                     1.4                5.0
# 5                                     1.4                5.0
# 6                                     1.4                5.0
# 7                                     1.4                5.0
# 8                                     1.4                5.0
# 9                                     1.4                5.0
# 10                                    1.4                5.0
# 11                                    1.4                5.0
# 12                                    1.4                5.0
# 13                                    1.4                5.0
# 14                                    1.4                5.0
# 15                                    1.4                5.0
# 16                                    1.4                5.0
# 17                                    1.4                5.0
# 18                                    1.4                5.0
# 19                                    1.4                5.0
# 20                                    1.4                5.0
# 21                                    1.4                5.0
# 22                                    1.4                5.0
# 23                                    1.4                5.0
# 24                                    1.4                5.0
# 25                                    1.4                5.0
# 26                                    1.4                5.0
# 27                                    1.4                5.0
# 28                                    1.4                5.0
# 29                                    1.4                5.0
# ...                                   ...                ...
# 6210                                  3.0             1269.0
# 6211                                  3.0             1269.0
# 6212                                  3.0             1269.0
# 6213                                  3.0             1269.0
# 6214                                  3.0             1269.0
# 6215                                  3.0             1269.0
# 6216                                  3.0             1269.0
# 6217                                  3.0             1269.0
# 6218                                  3.0             1269.0
# 6219                                  3.0             1269.0
# 6220                                  3.0             1269.0
# 6221                                  3.0             1269.0
# 6222                                  3.0             1269.0
# 6223                                  3.0             1269.0
# 6224                                  3.0             1269.0
# 6225                                  3.0             1269.0
# 6226                                  3.0             1269.0
# 6227                                  3.0             1269.0
# 6228                                  3.0             1269.0
# 6229                                  3.0             1269.0
# 6230                                  3.0             1269.0
# 6231                                  3.0             1269.0
# 6232                                  3.0             1269.0
# 6233                                  3.0             1269.0
# 6234                                  3.0             1269.0
# 6235                                  3.0             1269.0
# 6236                                  3.0             1269.0
# 6237                                  3.0             1269.0
# 6238                                  3.0             1269.0
# 6239                                  3.0             1269.0
#
# [6240 rows x 35 columns]

# %%
labeled_df['pros'][5]
# Out:
# 'Our voices have finally been heard. All the new systems are welcomed and your strategy is thoughtful and exciting. You show us personally that you care about each and every one of us. Feels G-R-R-E-E-A-T!'

# %%
#collapse reviews within companies
pd.set_option("display.max_colwidth", 1000)
#group by company
cons_docs = df.groupby(['company']).agg(' '.join(['cons'])).apply(lambda x: ", ".join(x)).to_frame()
#cons_docs = df.groupby(['company'])['cons'].apply(lambda text: ''.join(text.to_string(index=False))).str.replace('(\\n)', '').reset_index()
pros_docs = df.groupby(['company']).agg(' '.join(['pros'])).apply(lambda x: ", ".join(x)).to_frame()
#pros_docs = df.groupby(['company'])['pros'].apply(lambda text: ''.join(text.to_string(index=False))).str.replace('(\\n)', '').reset_index()
advice = df.groupby(['company'])['advice_to_management'].apply(lambda text: ''.join(text.to_string(index=False))).str.replace('(\\n)', '').reset_index()
num_stars = df.groupby(['company'])['overall_rating'].mean()
career_opps = df.groupby(['company'])['Career Opportunities'].mean()
comp_ben = df.groupby(['company'])['Compensation and Benefits'].mean()
culture = df.groupby(['company'])['Culture & Values'].mean()
management = df.groupby(['company'])['Senior Management'].mean()
workLife = df.groupby(['company'])['Work/Life Balance'].mean()

# %%
#df2 = collapsed_df['cons'].apply(lambda x: x.replace(',', '').replace('\\n',''))

# %%
cons_df = pd.merge(cons_docs, inhersight_df, on='company', how='outer')
pros_cons_df = pd.merge(cons_df, pros_docs, on='company', how='outer')
pca_df = pd.merge(pros_cons_df, advice, on='company', how='outer')
pca_star = pd.merge(pca_df, num_stars, on='company', how='outer')
career = pd.merge(pca_star, career_opps, on='company', how='outer')
comp = pd.merge(career, comp_ben, on='company', how='outer')
cultu = pd.merge(comp, culture, on='company', how='outer')
wlb = pd.merge(cultu, management, on='company', how='outer')
collapsed_df = pd.merge(cultu, workLife, on='company', how='outer')
#collapsed_df.head(1)

# %%
df2 = collapsed_df
df2['cons'] = collapsed_df['cons'].apply(lambda x: x.replace(',', '').replace('\\n','').replace('\n',''))
df2['pros'] = collapsed_df['pros'].apply(lambda x: x.replace(',', '').replace('\\n','').replace('\n',''))

# %%
len(df2['pros'][0])
# Out:
# 12992

# %%
len(df2['pros'][5])
# Out:
# 18069

# %%
#cons_df

# %%
import pickle

# %%
df2.to_pickle("./collapsed_review_data.pkl")

# %%
unpickled_df = pd.read_pickle("./collapsed_review_data.pkl")

# %%
unpickled_df['cons'][0]
# Out:
# 'The most tenure someone has there that is not the COO is 1 year.  Look at their blog to see how many employees have come and gone in a matter of months.  Wondering the reason for the turnover?  The CEO is verbally abusive and loves chaos and creating chaos.  He has no clue how to run a company.  Be sure to ask detailed questions about the current clients and profitability - they have never sold this platform to a single client. Company experiencing high staff Turnover Poor leadership. Untrustworthy. No transparency. Not all employees have accepted the new structure and can cause negativity throughout the office. Why does it seem that everyone is leaving a sinking ship? In the last 3 months more than half of the most competent people have left. During lunch and smoke breaks the topic #1 is applying for other jobs. What is going on that most of us are not hearing about? I can only recommend for new-comers to question the financials before taking a new job at 360 No cons here anymore. It is now a fun place to work and we are changing faster than expected.  I guess some of the people don\'t like the fast pace change but they will get over it and get on with themselves. It is nd has been needed. Lack of communication between departments and through the hierarchy. No systematic reviews nor bonuses/salary increases.  Products are mediocre despite the advertising. Technology varies depending on department no consistent protocols or processes for any of the operations. Can be extremely frustrating and the majority of the people have lots of duties beyond the scope of their jobs with very little training. There were not any cons. Unfortunately their claims to focus on customers and employees didn\'t turn out to be true. I can honestly say that I have never been happier to finally get out after some time here. The management makes you feel like you owe them something with no repayment with a salary increase or praise. It\'s give me give me until you finally cannot give anymore. The salaries are lacking because they promise a quarterly variable. RUN!!!! The bonus structure is a hoax. Don\'t a believe a word they say about the Quarterly Variable. You never get paid even close to your "target". It\'s a ploy to get you to sign the offer and in the door. The lacking of HR and administrative workers is insane. They will hire and hire sales people but  understaff and over work the admin side of the business. They cannot keep an HR position filled to save their life. This is mainly because the owner is so crooked and asks these people to "work around rules and regulations".  Be careful if they ever find an HR person that sticks around he/she will be just as crooked as him. Most importantly take a look at how many executives this company has run through over the years. If they don\'t agree with Ed or his new fancy ideas "they gone". This company has extremely high turn over. Most of the staff has been with the company less than 1 year. They have almost a complete company turn over every couple of years. Another complaint that ex employee have is they work so hard at 360 that it ruins their work/ life balance. It\'s hard to move on after working here because no company in their right mind makes you work so hard. You will be bored at every job after this.Ed is always pushing the HR newbies to push culture but doesn\'t want to back it up. He wants to seem concerned about the employees but without spending any of his money. Senior level management is constantly changing which leads to speculation from employees especially at remote locations. The company is at least 1 year behind in their industry if not more. CEO has plenty of ideas but no clue how to actually communicate how things are going to be accomplished none to mention at this time In every company we see things that we can improve but more than that its the way people contribute to each problem we encounter. Butwe continue to miss our numbers not because of sales team not performaing but b ...

# %%
collapsed_df_labeled_only = collapsed_df[pd.notnull(collapsed_df['Overall'])]
collapsed_df_labeled_only.index = range(len(collapsed_df_labeled_only.index)) #reset index
collapsed_df_labeled_only
#collapsed_df_labeled_only.to_csv('Data/1collapsed_df_with_IHS_reviews.csv')
collapsed_df_labeled_only.to_pickle("./labeled_only_collapsed_review_data.pkl")
